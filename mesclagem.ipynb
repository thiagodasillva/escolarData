# %%
import pandas as pd

# %% [markdown]
# ### recortar os as colunas dos dataframes de cada ano

# %%
df2007 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2007.csv")
df2007
# Out:
#         Ano        Região  UF  Código do Município      Nome do Município  \
# 0      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 1      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 2      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 3      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 4      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# ...     ...           ...  ..                  ...                    ...
# 33326  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33327  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33328  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33329  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33330  2007  Centro_Oeste  DF              5300108               BRASILIA
#
#       Localização        Rede Total_Abandono_EF2007 Total_Abandono_EM2007
# ...

# %%
df2008 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2008.csv")
df2008= df2008.iloc[:,[7,8]]
df2008
# Out:
#       Total_Abandono_EF2008 Total_Abandono_EM2008
# 0                       6.3                    --
# 1                       5.6                    --
# 2                       5.7                    --
# 3                       5.7                    --
# 4                       7.4                  14.2
# ...                     ...                   ...
# 65459                   2.5                   6.9
# 65460                     0                     0
# 65461                   0.1                   0.2
# 65462                   2.5                   6.9
# 65463                     2                   5.1
#
# [65464 rows x 2 columns]

# %%
df2009 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2009.csv")
df2009= df2009.iloc[:,[7,8]]
df2009
# Out:
#       Total_Abandono_EF2009 Total_Abandono_EM2009
# 0                      14.4                    --
# 1                       5.4                    --
# 2                       6.3                    --
# 3                       6.3                    --
# 4                       6.9                  14.1
# ...                     ...                   ...
# 65499                     2                   9.9
# 65500                     0                     0
# 65501                   0.1                   0.1
# 65502                     2                   9.7
# 65503                   1.5                   7.4
#
# [65504 rows x 2 columns]

# %%
df2010 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2010.csv")
df2010= df2010.iloc[:,[7,8]]
df2010
# Out:
#       Total_Abandono_EF2010 Total_Abandono_EM2010
# 0                       4.2                    --
# 1                       6.1                    --
# 2                         6                    --
# 3                         6                    --
# 4                       6.1                  14.1
# ...                     ...                   ...
# 65455                   1.4                   8.9
# 65456                     0                     0
# 65457                     0                   0.1
# 65458                   1.5                   8.8
# 65459                   1.1                   6.6
#
# [65460 rows x 2 columns]

# %%
df2011 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2011.csv")
df2011= df2011.iloc[:,[7,8]]
df2011
# Out:
#       Total_Abandono_EF2011 Total_Abandono_EM2011
# 0                       4.5                  11.1
# 1                       4.4                  11.1
# 2                       4.5                    --
# 3                         4                    --
# 4                       4.8                  11.1
# ...                     ...                   ...
# 33384                   1.2                   7.4
# 33385                   1.5                   9.8
# 33386                   0.1                   0.1
# 33387                   0.1                     0
# 33388                   1.5                    10
#
# [33389 rows x 2 columns]

# %%
df2012 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2012.csv")
df2012= df2012.iloc[:,[7,8]]
df2012
# Out:
#       Total_Abandono_EF2012 Total_Abandono_EM2012
# 0                       4.4                  13.6
# 1                       4.4                  13.6
# 2                         0                    --
# 3                         4                    --
# 4                       4.8                  13.6
# ...                     ...                   ...
# 65627                   1.4                   7.4
# 65628                   1.9                    10
# 65629                     0                   0.1
# 65630                     0                     0
# 65631                   1.9                  10.2
#
# [65632 rows x 2 columns]

# %%
df2013 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2013.csv")
df2013= df2013.iloc[:,[7,8]]
df2013
# Out:
#       Total_Abandono_EF2013 Total_Abandono_EM2013
# 0                       3.5                  11.1
# 1                       3.5                  11.1
# 2                         0                    --
# 3                       3.9                    --
# 4                       3.3                  11.1
# ...                     ...                   ...
# 65648                   1.1                   5.5
# 65649                   1.5                   7.4
# 65650                     0                   0.1
# 65651                     0                     0
# 65652                   1.5                   7.5
#
# [65653 rows x 2 columns]

# %%
df2014 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2014.csv")
df2014= df2014.iloc[:,[7,8]]
df2014
# Out:
#       Total_Abandono_EF2014 Total_Abandono_EM2014
# 0                       2.4                   9.3
# 1                       2.4                   9.3
# 2                         0                    --
# 3                       2.7                    --
# 4                       2.3                   9.3
# ...                     ...                   ...
# 65620                   1.2                   5.2
# 65621                   1.7                     7
# 65622                     0                   0.1
# 65623                     0                     0
# 65624                   1.7                   7.2
#
# [65625 rows x 2 columns]

# %%
df2015 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2015.csv")
df2015= df2015.iloc[:,[7,8]]
df2015
# Out:
#       Total_Abandono_EF2015 Total_Abandono_EM2015
# 0                       2.2                  11.2
# 1                       2.2                  11.2
# 2                       2.4                  11.2
# 3                         2                    --
# 4                       2.2                  11.2
# ...                     ...                   ...
# 65735                     1                   3.4
# 65736                   1.1                     4
# 65737                    --                   4.6
# 65738                   1.1                   3.9
# 65739                     0                     0
#
# [65740 rows x 2 columns]

# %%
df2016 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2016.csv")
df2016= df2016.iloc[:,[7,8]]
df2016
# Out:
#       Total_Abandono_EF2016 Total_Abandono_EM2016
# 0                       3.1                   10.6
# 1                       2.4                   28.6
# 2                       3.3                   10.4
# 3                       2.8                   10.6
# 4                       3.5                     --
# ...                     ...                    ...
# 65819                     0                    0.1
# 65820                   1.5                    4.9
# 65821                   1.2                    4.8
# 65822                   1.5                    4.8
# 65823                   1.5                    4.8
#
# [65824 rows x 2 columns]

# %%
df2017 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2017.csv")
df2017= df2017.iloc[:,[7,8]]
df2017
# Out:
#       Total_Abandono_EF2017 Total_Abandono_EM2017
# 0                       1.4                     7.2
# 1                       1.6                     7.4
# 2                       0.9                       0
# 3                       1.3                     7.2
# 4                       1.4                     7.4
# ...                     ...                     ...
# 65773                     0                       0
# 65774                   1.6                     6.1
# 65775                   1.6                     6.1
# 65776                   1.1                     5.3
# 65777                   1.1                     5.3
#
# [65778 rows x 2 columns]

# %%
df2018 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2018.csv")
df2018= df2018.iloc[:,[7,8]]
df2018
# Out:
#       Total_Abandono_EF2018 Total_Abandono_EM2018
# 0                       1.8                     6.8
# 1                       1.7                     7.1
# 2                       2.4                       0
# 3                       1.3                     6.8
# 4                       1.5                     7.1
# ...                     ...                     ...
# 65736                     0                       0
# 65737                     1                     4.5
# 65738                     1                     4.6
# 65739                   0.7                     2.4
# 65740                   0.7                     2.4
#
# [65741 rows x 2 columns]

# %%
df2019 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2019.csv")
df2019= df2019.iloc[:,[7,8]]
df2019
# Out:
#       Total_Abandono_EF2019 Total_Abandono_EM2019
# 0                       1.6                   5.8
# 1                       1.6                   6.3
# 2                       1.7                     0
# 3                       1.3                   5.8
# 4                       1.5                   6.3
# ...                     ...                   ...
# 65693                     0                     0
# 65694                   1.1                   4.7
# 65695                   1.1                   4.8
# 65696                   0.7                   2.8
# 65697                   0.7                   2.8
#
# [65698 rows x 2 columns]

# %%
df2020 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2020.csv")
df2020= df2020.iloc[:,[7,8]]
df2020
# Out:
#       Total_Abandono_EF2020 Total_Abandono_EM2020
# 0                       7.4                     0
# 1                       0.6                     0
# 2                      38.5                     0
# 3                      14.2                     0
# 4                         0                     0
# ...                     ...                   ...
# 65657                     0                     0
# 65658                   0.2                   0.7
# 65659                   0.2                   0.7
# 65660                   0.1                     0
# 65661                   0.1                     0
#
# [65662 rows x 2 columns]

# %%
df2021 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2021.csv")
df2021= df2021.iloc[:,[7,8]]
df2021
# Out:
#       Total_Abandono_EF2021 Total_Abandono_EF2021.1
# 0                       0.2                     1.4
# 1                       0.3                     1.6
# 2                         0                       0
# 3                       0.5                     1.4
# 4                       0.5                     1.6
# ...                     ...                     ...
# 65570                     0                       0
# 65571                   0.2                     1.3
# 65572                   0.1                     1.4
# 65573                   0.2                     1.3
# 65574                   0.2                     1.3
#
# [65575 rows x 2 columns]

# %%
df2022 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2022.csv")
df2022 = df2022.iloc[:,[7,8]]
df2022
# Out:
#       Total_Abandono_EF2022 Total_Abandono_EM2022
# 0                       0.7                   5.8
# 1                       0.8                     6
# 2                         0                     0
# 3                       1.6                   5.8
# 4                         2                     6
# ...                     ...                   ...
# 65592                     0                     0
# 65593                   0.7                   4.6
# 65594                   0.8                   4.7
# 65595                   0.6                   3.8
# 65596                   0.6                   3.8
#
# [65597 rows x 2 columns]

# %%
df2023 = pd.read_csv("rendimento_escolar/Dados Tratados/dadosTratados2023.csv")
df2023 = df2023.iloc[:,[7,8]]
df2023
# Out:
#       Total_Abandono_EF2023 Total_Abandono_EM2023
# 0                         1                   0.4
# 1                       0.9                   0.3
# 2                       1.4                     2
# 3                       0.3                   0.4
# 4                       0.3                   0.3
# ...                     ...                   ...
# 65624                     0                     0
# 65625                   0.8                   3.8
# 65626                   0.8                   3.9
# 65627                   0.3                   2.1
# 65628                   0.3                   2.1
#
# [65629 rows x 2 columns]

# %% [markdown]
# ### concatenar os dataframes dos diferentes anos e salvei em um dataframe com o nome df_final, tambem salvei em uma planilha

# %%
dataframes= [df2007,df2008,df2009,df2010,df2011,df2012,df2013,df2014,df2015,df2016,df2007,df2018,df2019,df2020,df2021,df2022,df2023]

# %%
df_final = pd.concat(dataframes, axis=1)

# %%
df_final.to_csv("df_finalGenerico.csv", sep=",", index=False)

# %%
df_final
# Out:
#           Ano Região   UF  Código do Município      Nome do Município  \
# 0      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 1      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 2      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 3      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 4      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# ...       ...    ...  ...                  ...                    ...
# 65819     NaN    NaN  NaN                  NaN                    NaN
# 65820     NaN    NaN  NaN                  NaN                    NaN
# 65821     NaN    NaN  NaN                  NaN                    NaN
# 65822     NaN    NaN  NaN                  NaN                    NaN
# 65823     NaN    NaN  NaN                  NaN                    NaN
#
#       Localização       Rede Total_Abandono_EF2007 Total_Abandono_EM2007  \
# ...

# %%
# Lista das colunas que você quer manter (adicione as suas)
colunas_selecionadas = [
    'Ano', 
    'Região', 
    'UF', 
    'Código do Município', 
    'Nome do Município',
    'Localização',
    'Rede',
    'Total_Abandono_EF2007', 
    'Total_Abandono_EM2007',
    
]

# Filtro + seleção de colunas em uma única operação
df_filtrado = df2007[
   ( (df2007['Localização'] == 'Rural') | (df2007['Localização'] == 'Urbana'))
    & (df2007['Rede'] == 'Total')
][colunas_selecionadas].copy()

# Resetar índice (opcional)
df_filtrado = df_filtrado.reset_index(drop=True)

# %%
df_filtrado
# Out:
#        Ano        Região  UF  Código do Município      Nome do Município  \
# 0     2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 1     2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 2     2007         Norte  RO              1100023              ARIQUEMES
# 3     2007         Norte  RO              1100023              ARIQUEMES
# 4     2007         Norte  RO              1100031                 CABIXI
# ...    ...           ...  ..                  ...                    ...
# 5251  2007  Centro_Oeste  GO              5222203               VILA BOA
# 5252  2007  Centro_Oeste  GO              5222302          VILA PROPICIO
# 5253  2007  Centro_Oeste  GO              5222302          VILA PROPICIO
# 5254  2007  Centro_Oeste  DF              5300108               BRASILIA
# 5255  2007  Centro_Oeste  DF              5300108               BRASILIA
#
#      Localização   Rede Total_Abandono_EF2007 Total_Abandono_EM2007
# ...

# %%
# Supondo que seu dataframe se chame df_filtrado
df_pivoted = df_filtrado.pivot(
    index=['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município', 'Rede'],
    columns='Localização',
    values=['Total_Abandono_EF2007', 'Total_Abandono_EM2007']
)

# Resetar o índice para transformar os níveis do multi-índice em colunas normais
df_pivoted = df_pivoted.reset_index()

# Renomear as colunas para ficarem mais claras
df_pivoted.columns = [
    'Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município', 'Rede',
    'Total_Abandono_EF2007_Rural', 'Total_Abandono_EF2007_Urbana',
    'Total_Abandono_EM2007_Rural', 'Total_Abandono_EM2007_Urbana'
]

# Reordenar as colunas se necessário
df_pivoted = df_pivoted[[
    'Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município', 'Rede',
    'Total_Abandono_EF2007_Rural', 'Total_Abandono_EF2007_Urbana',
    'Total_Abandono_EM2007_Rural', 'Total_Abandono_EM2007_Urbana'
]]

# %%
df_pivoted
# Out:
#        Ano        Região  UF  Código do Município Nome do Município   Rede  \
# 0     2007  Centro_Oeste  DF              5300108          BRASILIA  Total
# 1     2007  Centro_Oeste  GO              5200050   ABADIA DE GOIAS  Total
# 2     2007  Centro_Oeste  GO              5200100         ABADIANIA  Total
# 3     2007  Centro_Oeste  GO              5200134           ACREUNA  Total
# 4     2007  Centro_Oeste  GO              5200159         ADELANDIA  Total
# ...    ...           ...  ..                  ...               ...    ...
# 2703  2007         Norte  TO              1721208    TOCANTINOPOLIS  Total
# 2704  2007         Norte  TO              1721257          TUPIRAMA  Total
# 2705  2007         Norte  TO              1721307        TUPIRATINS  Total
# 2706  2007         Norte  TO              1722081      WANDERLANDIA  Total
# 2707  2007         Norte  TO              1722107           XAMBIOA  Total
#
#      Total_Abandono_EF2007_Rural Total_Abandono_EF2007_Urbana  \
# ...

# %%
df_nMatriculas = pd.read_csv("alunos_matriculados/matriculas_detalhadas_2007.csv")
df_nMatriculas
# Out:
#       CO_MUNICIPIO             NO_UF           NO_MUNICIPIO  \
# 0          1100015          Rondônia  Alta Floresta D'Oeste
# 1          1100023          Rondônia              Ariquemes
# 2          1100031          Rondônia                 Cabixi
# 3          1100049          Rondônia                 Cacoal
# 4          1100056          Rondônia             Cerejeiras
# ...            ...               ...                    ...
# 5559       5222005             Goiás             Vianópolis
# 5560       5222054             Goiás         Vicentinópolis
# 5561       5222203             Goiás               Vila Boa
# 5562       5222302             Goiás          Vila Propício
# 5563       5300108  Distrito Federal               Brasília
#
#       QT_MAT_BAS_Privada_Urbana  QT_MAT_BAS_Pública_Rural  \
# 0                          91.0                    2565.0
# 1                        2938.0                    3252.0
# 2                           0.0                      51.0
# ...
