# %%
import pandas as pd

# %% [markdown]
# ### recortar os as colunas dos dataframes de cada ano

# %%
df2007 = pd.read_csv("Dados Tratados/dadosTratados2007.csv")
df2007
# Out:
#         Ano        Região  UF  Código do Município      Nome do Município  \
# 0      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 1      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 2      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 3      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# 4      2007         Norte  RO              1100015  ALTA FLORESTA D'OESTE
# ...     ...           ...  ..                  ...                    ...
# 33326  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33327  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33328  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33329  2007  Centro_Oeste  DF              5300108               BRASILIA
# 33330  2007  Centro_Oeste  DF              5300108               BRASILIA
#
#       Localização Total_abandono_EF2007 Total_abandono_EM2007
# ...

# %%
df2008 = pd.read_csv("Dados Tratados/dadosTratados2008.csv")
df2008= df2008.iloc[:,[6,7]]
df2008
# Out:
#       Total_abandono_EF2008 Total_abandono_EM2008
# 0                         0                    --
# 1                         0                    --
# 2                         0                    --
# 3                         0                    --
# 4                         0                  19.7
# ...                     ...                   ...
# 65459                   1.5                   7.8
# 65460                    --                     0
# 65461                   0.2                   0.2
# 65462                   1.5                   7.6
# 65463                   1.2                   5.8
#
# [65464 rows x 2 columns]

# %%
df2009 = pd.read_csv("Dados Tratados/dadosTratados2009.csv")
df2009= df2009.iloc[:,[6,7]]
df2009

# %%
df2010 = pd.read_csv("Dados Tratados/dadosTratados2010.csv")
df2010= df2010.iloc[:,[6,7]]
df2010

# %%
df2011 = pd.read_csv("Dados Tratados/dadosTratados2011.csv")
df2011= df2011.iloc[:,[6,7]]
df2011

# %%
df2012 = pd.read_csv("Dados Tratados/dadosTratados2012.csv")
df2012= df2012.iloc[:,[6,7]]
df2012

# %%
df2013 = pd.read_csv("Dados Tratados/dadosTratados2013.csv")
df2013= df2013.iloc[:,[6,7]]
df2013

# %%
df2014 = pd.read_csv("Dados Tratados/dadosTratados2014.csv")
df2014= df2014.iloc[:,[6,7]]
df2014

# %%
df2015 = pd.read_csv("Dados Tratados/dadosTratados2015.csv")
df2015= df2015.iloc[:,[6,7]]
df2015

# %% [markdown]
# ### concatenar os dataframes dos diferentes anos e salvei em um dataframe com o nome df_final, tambem salvei em uma planilha

# %%
dataframes= [df2007,df2008,df2009,df2010,df2011,df2012,df2013,df2014,df2015]

# %%
df_final = pd.concat(dataframes, axis=1)

# %%
df_final.to_csv("df_final.csv", sep=",", index=False)

# %%
df_final
# Out:
#           Ano Região   UF  Código do Município      Nome do Município  \
# 0      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 1      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 2      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 3      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# 4      2007.0  Norte   RO            1100015.0  ALTA FLORESTA D'OESTE
# ...       ...    ...  ...                  ...                    ...
# 65735     NaN    NaN  NaN                  NaN                    NaN
# 65736     NaN    NaN  NaN                  NaN                    NaN
# 65737     NaN    NaN  NaN                  NaN                    NaN
# 65738     NaN    NaN  NaN                  NaN                    NaN
# 65739     NaN    NaN  NaN                  NaN                    NaN
#
#       Localização Total_abandono_EF2007 Total_abandono_EM2007  \
# 0           Rural                   4.3                    --
# ...
