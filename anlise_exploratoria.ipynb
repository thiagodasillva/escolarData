# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados_df= pd.read_csv('analise_robustaFINAL.csv')

# %% [markdown]
# ### entendendo melhor os dados

# %%
dados_df.head()
# Out:
#      Estado  UF  IDHM Educação 2012  IDHM Educação 2013  IDHM Educação 2014  \
# 0      Acre  AC               0.649               0.658               0.679
# 1   Alagoas  AL               0.587               0.573               0.599
# 2     Amapá  AP               0.659               0.714               0.688
# 3  Amazonas  AM               0.632               0.659               0.667
# 4     Bahia  BA               0.593               0.594               0.619
#
#    IDHM Educação 2015  IDHM Educação 2016  IDHM Educação 2017  \
# 0               0.679               0.704               0.671
# 1               0.605               0.635               0.634
# 2               0.690               0.709               0.700
# 3               0.686               0.705               0.732
# 4               0.640               0.656               0.655
#
#    IDHM Educação 2018  IDHM Educação 2019  ...  Taxa_Participacao_2018  \
# ...

# %%
print(dados_df.shape)
# Out:
# (27, 139)

# %%
dados_df.columns
# Out:
# Index(['Estado', 'UF', 'IDHM Educação 2012', 'IDHM Educação 2013',
#        'IDHM Educação 2014', 'IDHM Educação 2015', 'IDHM Educação 2016',
#        'IDHM Educação 2017', 'IDHM Educação 2018', 'IDHM Educação 2019',
#        ...
#        'Taxa_Participacao_2018', 'Taxa_Desocupacao_2019',
#        'Nivel_Ocupacao_2019', 'Taxa_Participacao_2019',
#        'Taxa_Desocupacao_2020', 'Nivel_Ocupacao_2020',
#        'Taxa_Participacao_2020', 'Taxa_Desocupacao_2021',
#        'Nivel_Ocupacao_2021', 'Taxa_Participacao_2021'],
#       dtype='object', length=139)

# %%
(dados_df.describe()).astype(int)
# Out:
#        IDHM Educação 2012  IDHM Educação 2013  IDHM Educação 2014  \
# count                  27                  27                  27
# mean                    0                   0                   0
# std                     0                   0                   0
# min                     0                   0                   0
# 25%                     0                   0                   0
# 50%                     0                   0                   0
# 75%                     0                   0                   0
# max                     0                   0                   0
#
#        IDHM Educação 2015  IDHM Educação 2016  IDHM Educação 2017  \
# count                  27                  27                  27
# mean                    0                   0                   0
# std                     0                   0                   0
# min                     0                   0                   0
# ...

# %%
dados_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 139 entries, Estado to Taxa_Participacao_2021
# dtypes: float64(112), int64(24), object(3)
# memory usage: 29.4+ KB

# %%
numeric_features = dados_df.select_dtypes(include=['number']).columns 

plt.figure(figsize=(20,20))

for i in range(len(numeric_features)):
    plt.subplot(11, 6, i+1)  # Grid 11x6 para 66 gráficos
    sns.kdeplot(x=dados_df[numeric_features[i]], shade=True, color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()  # Ajusta o layout para evitar sobreposição

# Exibindo o gráfico
plt.show()
# Out:
# C:\Users\valderez\AppData\Local\Temp\ipykernel_39532\3408557384.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=dados_df[numeric_features[i]], shade=True, color='b')
# C:\Users\valderez\AppData\Local\Temp\ipykernel_39532\3408557384.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=dados_df[numeric_features[i]], shade=True, color='b')
# C:\Users\valderez\AppData\Local\Temp\ipykernel_39532\3408557384.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=dados_df[numeric_features[i]], shade=True, color='b')
# ...

# %% [markdown]
# ## correlação dos valores de cada ano usando o abandono do Encino Fundamental

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2012': 'qtd_familias_2012'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2012': 'valor_medio_2012'})

dados_df[['Abandono_EF2012','valor_medio_2012','qtd_familias_2012','IDHM Educação 2012','IDHM Renda 2012','Índice de Atkinson - Educação 2012','Índice de Atkinson - Renda 2012','Renda per capita 2012','Índice de Gini 2012','Taxa_Desocupacao_2012','Nivel_Ocupacao_2012','Taxa_Participacao_2012']].corr()
# Out:
#                                     Abandono_EF2012  valor_medio_2012  \
# Abandono_EF2012                            1.000000         -0.059134
# valor_medio_2012                          -0.059134          1.000000
# qtd_familias_2012                          0.885140         -0.228185
# IDHM Educação 2012                        -0.407473         -0.350410
# IDHM Renda 2012                           -0.292910         -0.532823
# Índice de Atkinson - Educação 2012         0.282819          0.342438
# Índice de Atkinson - Renda 2012            0.257954          0.416201
# Renda per capita 2012                     -0.270016         -0.555202
# Índice de Gini 2012                        0.263215          0.298905
# Taxa_Desocupacao_2012                      0.436906          0.314345
# Nivel_Ocupacao_2012                       -0.352931         -0.349337
# Taxa_Participacao_2012                    -0.281787         -0.318316
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2012','valor_medio_2012','qtd_familias_2012','IDHM Educação 2012','IDHM Renda 2012','Índice de Atkinson - Educação 2012','Índice de Atkinson - Renda 2012','Renda per capita 2012','Índice de Gini 2012','Taxa_Desocupacao_2012','Nivel_Ocupacao_2012','Taxa_Participacao_2012']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2013': 'qtd_familias_2013'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2013': 'valor_medio_2013'})

dados_df[['Abandono_EF2013','valor_medio_2013','qtd_familias_2013','IDHM Educação 2013','IDHM Renda 2013','Índice de Atkinson - Educação 2013','Índice de Atkinson - Renda 2013','Renda per capita 2013','Índice de Gini 2013','Taxa_Desocupacao_2013','Nivel_Ocupacao_2013','Taxa_Participacao_2013']].corr()
# Out:
#                                     Abandono_EF2013  valor_medio_2013  \
# Abandono_EF2013                            1.000000          0.034833
# valor_medio_2013                           0.034833          1.000000
# qtd_familias_2013                          0.882879         -0.125897
# IDHM Educação 2013                        -0.394629         -0.397830
# IDHM Renda 2013                           -0.310038         -0.650077
# Índice de Atkinson - Educação 2013         0.225352          0.537714
# Índice de Atkinson - Renda 2013            0.265629          0.448437
# Renda per capita 2013                     -0.273296         -0.634391
# Índice de Gini 2013                        0.211319          0.398907
# Taxa_Desocupacao_2013                      0.420470          0.394445
# Nivel_Ocupacao_2013                       -0.339327         -0.502167
# Taxa_Participacao_2013                    -0.270006         -0.480068
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2013','valor_medio_2013','qtd_familias_2013','IDHM Educação 2013','IDHM Renda 2013','Índice de Atkinson - Educação 2013','Índice de Atkinson - Renda 2013','Renda per capita 2013','Índice de Gini 2013','Taxa_Desocupacao_2013','Nivel_Ocupacao_2013','Taxa_Participacao_2013']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2014': 'qtd_familias_2014'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2014': 'valor_medio_2014'})

dados_df[['Abandono_EF2014','valor_medio_2014','qtd_familias_2014','IDHM Educação 2014','IDHM Renda 2014','Índice de Atkinson - Educação 2014','Índice de Atkinson - Renda 2014','Renda per capita 2014','Índice de Gini 2014','Taxa_Desocupacao_2014','Nivel_Ocupacao_2014','Taxa_Participacao_2014']].corr()
# Out:
#                                     Abandono_EF2014  valor_medio_2014  \
# Abandono_EF2014                            1.000000          0.028893
# valor_medio_2014                           0.028893          1.000000
# qtd_familias_2014                          0.891788         -0.108491
# IDHM Educação 2014                        -0.340036         -0.390789
# IDHM Renda 2014                           -0.260106         -0.661275
# Índice de Atkinson - Educação 2014         0.148462          0.552078
# Índice de Atkinson - Renda 2014            0.214402          0.460338
# Renda per capita 2014                     -0.228955         -0.633418
# Índice de Gini 2014                        0.240883          0.324163
# Taxa_Desocupacao_2014                      0.417782          0.396711
# Nivel_Ocupacao_2014                       -0.324194         -0.494133
# Taxa_Participacao_2014                    -0.251327         -0.468858
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2014','valor_medio_2014','qtd_familias_2014','IDHM Educação 2014','IDHM Renda 2014','Índice de Atkinson - Educação 2014','Índice de Atkinson - Renda 2014','Renda per capita 2014','Índice de Gini 2014','Taxa_Desocupacao_2014','Nivel_Ocupacao_2014','Taxa_Participacao_2014']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2015': 'qtd_familias_2015'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2015': 'valor_medio_2015'})

dados_df[['Abandono_EF2015','valor_medio_2015','qtd_familias_2015','IDHM Educação 2015','IDHM Renda 2015','Índice de Atkinson - Educação 2015','Índice de Atkinson - Renda 2015','Renda per capita 2015','Índice de Gini 2015','Taxa_Desocupacao_2015','Nivel_Ocupacao_2015','Taxa_Participacao_2015']].corr()
# Out:
#                                     Abandono_EF2015  valor_medio_2015  \
# Abandono_EF2015                            1.000000          0.075634
# valor_medio_2015                           0.075634          1.000000
# qtd_familias_2015                          0.861718         -0.071279
# IDHM Educação 2015                        -0.333068         -0.429818
# IDHM Renda 2015                           -0.306497         -0.596642
# Índice de Atkinson - Educação 2015         0.177113          0.532161
# Índice de Atkinson - Renda 2015            0.230531          0.621517
# Renda per capita 2015                     -0.265749         -0.555374
# Índice de Gini 2015                        0.165730          0.486416
# Taxa_Desocupacao_2015                      0.393671          0.417694
# Nivel_Ocupacao_2015                       -0.310894         -0.512187
# Taxa_Participacao_2015                    -0.243516         -0.484071
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2015','valor_medio_2015','qtd_familias_2015','IDHM Educação 2015','IDHM Renda 2015','Índice de Atkinson - Educação 2015','Índice de Atkinson - Renda 2015','Renda per capita 2015','Índice de Gini 2015','Taxa_Desocupacao_2015','Nivel_Ocupacao_2015','Taxa_Participacao_2015']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2016': 'qtd_familias_2016'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2016': 'valor_medio_2016'})

dados_df[['Abandono_EF2016','valor_medio_2016','qtd_familias_2016','IDHM Educação 2016','IDHM Renda 2016','Índice de Atkinson - Educação 2016','Índice de Atkinson - Renda 2016','Renda per capita 2016','Índice de Gini 2016','Taxa_Desocupacao_2016','Nivel_Ocupacao_2016','Taxa_Participacao_2016']].corr()
# Out:
#                                     Abandono_EF2016  valor_medio_2016  \
# Abandono_EF2016                            1.000000          0.073727
# valor_medio_2016                           0.073727          1.000000
# qtd_familias_2016                          0.877738         -0.071292
# IDHM Educação 2016                        -0.324854         -0.407189
# IDHM Renda 2016                           -0.303750         -0.643526
# Índice de Atkinson - Educação 2016         0.159887          0.505397
# Índice de Atkinson - Renda 2016            0.213579          0.556844
# Renda per capita 2016                     -0.260430         -0.596152
# Índice de Gini 2016                        0.209256          0.475825
# Taxa_Desocupacao_2016                      0.418552          0.417668
# Nivel_Ocupacao_2016                       -0.329406         -0.512163
# Taxa_Participacao_2016                    -0.257067         -0.484050
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2016','valor_medio_2016','qtd_familias_2016','IDHM Educação 2016','IDHM Renda 2016','Índice de Atkinson - Educação 2016','Índice de Atkinson - Renda 2016','Renda per capita 2016','Índice de Gini 2016','Taxa_Desocupacao_2016','Nivel_Ocupacao_2016','Taxa_Participacao_2016']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2017': 'qtd_familias_2017'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2017': 'valor_medio_2017'})

dados_df[['Abandono_EF2017','valor_medio_2017','qtd_familias_2017','IDHM Educação 2017','IDHM Renda 2017','Índice de Atkinson - Educação 2017','Índice de Atkinson - Renda 2017','Renda per capita 2017','Índice de Gini 2017','Taxa_Desocupacao_2017','Nivel_Ocupacao_2017','Taxa_Participacao_2017']].corr()
# Out:
#                                     Abandono_EF2017  valor_medio_2017  \
# Abandono_EF2017                            1.000000          0.076633
# valor_medio_2017                           0.076633          1.000000
# qtd_familias_2017                          0.865255         -0.047753
# IDHM Educação 2017                        -0.266582         -0.422363
# IDHM Renda 2017                           -0.239886         -0.627108
# Índice de Atkinson - Educação 2017         0.159165          0.495842
# Índice de Atkinson - Renda 2017            0.243560          0.603920
# Renda per capita 2017                     -0.217205         -0.575993
# Índice de Gini 2017                        0.324344          0.495102
# Taxa_Desocupacao_2017                      0.384183          0.443059
# Nivel_Ocupacao_2017                       -0.276138         -0.519338
# Taxa_Participacao_2017                    -0.202633         -0.483398
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2017','valor_medio_2017','qtd_familias_2017','IDHM Educação 2017','IDHM Renda 2017','Índice de Atkinson - Educação 2017','Índice de Atkinson - Renda 2017','Renda per capita 2017','Índice de Gini 2017','Taxa_Desocupacao_2017','Nivel_Ocupacao_2017','Taxa_Participacao_2017']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2018': 'qtd_familias_2018'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2018': 'valor_medio_2018'})

dados_df[['Abandono_EF2018','valor_medio_2018','qtd_familias_2018','IDHM Educação 2018','IDHM Renda 2018','Índice de Atkinson - Educação 2018','Índice de Atkinson - Renda 2018','Renda per capita 2018','Índice de Gini 2018','Taxa_Desocupacao_2018','Nivel_Ocupacao_2018','Taxa_Participacao_2018']].corr()
# Out:
#                                     Abandono_EF2018  valor_medio_2018  \
# Abandono_EF2018                            1.000000          0.068057
# valor_medio_2018                           0.068057          1.000000
# qtd_familias_2018                          0.836517         -0.054561
# IDHM Educação 2018                        -0.321034         -0.355512
# IDHM Renda 2018                           -0.264298         -0.590735
# Índice de Atkinson - Educação 2018         0.155435          0.456788
# Índice de Atkinson - Renda 2018            0.194691          0.624845
# Renda per capita 2018                     -0.233440         -0.548376
# Índice de Gini 2018                        0.257997          0.487757
# Taxa_Desocupacao_2018                      0.346861          0.448228
# Nivel_Ocupacao_2018                       -0.243842         -0.509117
# Taxa_Participacao_2018                    -0.175663         -0.468423
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2018','valor_medio_2018','qtd_familias_2018','IDHM Educação 2018','IDHM Renda 2018','Índice de Atkinson - Educação 2018','Índice de Atkinson - Renda 2018','Renda per capita 2018','Índice de Gini 2018','Taxa_Desocupacao_2018','Nivel_Ocupacao_2018','Taxa_Participacao_2018']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2019': 'qtd_familias_2019'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2019': 'valor_medio_2019'})

dados_df[['Abandono_EF2019','valor_medio_2019','qtd_familias_2019','IDHM Educação 2019','IDHM Renda 2019','Índice de Atkinson - Educação 2019','Índice de Atkinson - Renda 2019','Renda per capita 2019','Índice de Gini 2019','Taxa_Desocupacao_2019','Nivel_Ocupacao_2019','Taxa_Participacao_2019']].corr()
# Out:
#                                     Abandono_EF2019  valor_medio_2019  \
# Abandono_EF2019                            1.000000          0.063305
# valor_medio_2019                           0.063305          1.000000
# qtd_familias_2019                          0.814208         -0.060641
# IDHM Educação 2019                        -0.242865         -0.244349
# IDHM Renda 2019                           -0.224266         -0.574643
# Índice de Atkinson - Educação 2019         0.129439          0.415517
# Índice de Atkinson - Renda 2019            0.205911          0.625092
# Renda per capita 2019                     -0.190772         -0.515774
# Índice de Gini 2019                        0.237529          0.490974
# Taxa_Desocupacao_2019                      0.330273          0.442350
# Nivel_Ocupacao_2019                       -0.210546         -0.487003
# Taxa_Participacao_2019                    -0.139021         -0.442730
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2019','valor_medio_2019','qtd_familias_2019','IDHM Educação 2019','IDHM Renda 2019','Índice de Atkinson - Educação 2019','Índice de Atkinson - Renda 2019','Renda per capita 2019','Índice de Gini 2019','Taxa_Desocupacao_2019','Nivel_Ocupacao_2019','Taxa_Participacao_2019']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2020': 'qtd_familias_2020'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2020': 'valor_medio_2020'})

dados_df[['Abandono_EF2020','valor_medio_2020','qtd_familias_2020','IDHM Educação 2020','IDHM Renda 2020','Índice de Atkinson - Educação 2020','Índice de Atkinson - Renda 2020','Renda per capita 2020','Índice de Gini 2020','Taxa_Desocupacao_2020','Nivel_Ocupacao_2020','Taxa_Participacao_2020']].corr()
# Out:
#                                     Abandono_EF2020  valor_medio_2020  \
# Abandono_EF2020                            1.000000         -0.094111
# valor_medio_2020                          -0.094111          1.000000
# qtd_familias_2020                          0.792046         -0.195147
# IDHM Educação 2020                        -0.142196         -0.104627
# IDHM Renda 2020                           -0.167114         -0.405982
# Índice de Atkinson - Educação 2020         0.179534          0.200525
# Índice de Atkinson - Renda 2020            0.044550          0.275748
# Renda per capita 2020                     -0.167950         -0.357143
# Índice de Gini 2020                        0.107784          0.135531
# Taxa_Desocupacao_2020                      0.269669          0.175876
# Nivel_Ocupacao_2020                       -0.234137         -0.198848
# Taxa_Participacao_2020                    -0.191184         -0.183144
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2020','valor_medio_2020','qtd_familias_2020','IDHM Educação 2020','IDHM Renda 2020','Índice de Atkinson - Educação 2020','Índice de Atkinson - Renda 2020','Renda per capita 2020','Índice de Gini 2020','Taxa_Desocupacao_2020','Nivel_Ocupacao_2020','Taxa_Participacao_2020']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2021': 'qtd_familias_2021'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2021': 'valor_medio_2021'})

dados_df[['Abandono_EF2021','valor_medio_2021','qtd_familias_2021','IDHM Educação 2021','IDHM Renda 2021','Índice de Atkinson - Educação 2021','Índice de Atkinson - Renda 2021','Renda per capita 2021','Índice de Gini 2021','Taxa_Desocupacao_2021','Nivel_Ocupacao_2021','Taxa_Participacao_2021']].corr()
# Out:
#                                     Abandono_EF2021  valor_medio_2021  \
# Abandono_EF2021                            1.000000         -0.000795
# valor_medio_2021                          -0.000795          1.000000
# qtd_familias_2021                          0.786204         -0.165351
# IDHM Educação 2021                        -0.150155         -0.343736
# IDHM Renda 2021                           -0.184604         -0.367424
# Índice de Atkinson - Educação 2021         0.124975          0.193753
# Índice de Atkinson - Renda 2021            0.164293          0.367613
# Renda per capita 2021                     -0.152717         -0.330864
# Índice de Gini 2021                        0.160856          0.259657
# Taxa_Desocupacao_2021                      0.313895          0.244356
# Nivel_Ocupacao_2021                       -0.164809         -0.270099
# Taxa_Participacao_2021                    -0.088122         -0.245624
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EF2021','valor_medio_2021','qtd_familias_2021','IDHM Educação 2021','IDHM Renda 2021','Índice de Atkinson - Educação 2021','Índice de Atkinson - Renda 2021','Renda per capita 2021','Índice de Gini 2021','Taxa_Desocupacao_2021','Nivel_Ocupacao_2021','Taxa_Participacao_2021']].corr())
plt.show()

# %% [markdown]
# #### o ano de 2022 não tem dados de nenhuma das variaveis e o ano de 2023 tem valores apenas para as variaveis de abandomo escolar, valores medios do bolsa familia e quantidade de familias que receber o auxilio

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2023': 'qtd_familias_2023'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2023': 'valor_medio_2023'})

dados_df[['Abandono_EF2023','valor_medio_2023','qtd_familias_2023']].corr()
# Out:
#                    Abandono_EF2023  valor_medio_2023  qtd_familias_2023
# Abandono_EF2023           1.000000         -0.201111           0.823763
# valor_medio_2023         -0.201111          1.000000          -0.423710
# qtd_familias_2023         0.823763         -0.423710           1.000000

# %%
plt.figure(figsize=(7,7))
sns.heatmap(dados_df[['Abandono_EF2023','valor_medio_2023','qtd_familias_2023']].corr())
plt.show()

# %% [markdown]
# ### plotando graficos de disperção

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2012', 'qtd_familias_2012', 'IDHM Educação 2012', 
               'IDHM Renda 2012', 'Índice de Atkinson - Educação 2012', 
               'Índice de Atkinson - Renda 2012', 'Renda per capita 2012', 
               'Índice de Gini 2012', 'Taxa_Desocupacao_2012', 
               'Nivel_Ocupacao_2012', 'Taxa_Participacao_2012']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2012", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2012')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2012')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2013', 'qtd_familias_2013', 'IDHM Educação 2013', 
               'IDHM Renda 2013', 'Índice de Atkinson - Educação 2013', 
               'Índice de Atkinson - Renda 2013', 'Renda per capita 2013', 
               'Índice de Gini 2013', 'Taxa_Desocupacao_2013', 
               'Nivel_Ocupacao_2013', 'Taxa_Participacao_2013']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2013", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2013')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2013')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2014', 'qtd_familias_2014', 'IDHM Educação 2014', 
               'IDHM Renda 2014', 'Índice de Atkinson - Educação 2014', 
               'Índice de Atkinson - Renda 2014', 'Renda per capita 2014', 
               'Índice de Gini 2014', 'Taxa_Desocupacao_2014', 
               'Nivel_Ocupacao_2014', 'Taxa_Participacao_2014']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2014", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2014')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2014')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2015', 'qtd_familias_2015', 'IDHM Educação 2015', 
               'IDHM Renda 2015', 'Índice de Atkinson - Educação 2015', 
               'Índice de Atkinson - Renda 2015', 'Renda per capita 2015', 
               'Índice de Gini 2015', 'Taxa_Desocupacao_2015', 
               'Nivel_Ocupacao_2015', 'Taxa_Participacao_2015']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2015", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2015')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2015')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2016', 'qtd_familias_2016', 'IDHM Educação 2016', 
               'IDHM Renda 2016', 'Índice de Atkinson - Educação 2016', 
               'Índice de Atkinson - Renda 2016', 'Renda per capita 2016', 
               'Índice de Gini 2016', 'Taxa_Desocupacao_2016', 
               'Nivel_Ocupacao_2016', 'Taxa_Participacao_2016']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2016", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2016')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2016')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2017', 'qtd_familias_2017', 'IDHM Educação 2017', 
               'IDHM Renda 2017', 'Índice de Atkinson - Educação 2017', 
               'Índice de Atkinson - Renda 2017', 'Renda per capita 2017', 
               'Índice de Gini 2017', 'Taxa_Desocupacao_2017', 
               'Nivel_Ocupacao_2017', 'Taxa_Participacao_2017']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2017", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2017')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2017')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2018', 'qtd_familias_2018', 'IDHM Educação 2018', 
               'IDHM Renda 2018', 'Índice de Atkinson - Educação 2018', 
               'Índice de Atkinson - Renda 2018', 'Renda per capita 2018', 
               'Índice de Gini 2018', 'Taxa_Desocupacao_2018', 
               'Nivel_Ocupacao_2018', 'Taxa_Participacao_2018']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2018", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2018')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2018')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2019', 'qtd_familias_2019', 'IDHM Educação 2019', 
               'IDHM Renda 2019', 'Índice de Atkinson - Educação 2019', 
               'Índice de Atkinson - Renda 2019', 'Renda per capita 2019', 
               'Índice de Gini 2019', 'Taxa_Desocupacao_2019', 
               'Nivel_Ocupacao_2019', 'Taxa_Participacao_2019']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2019", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2019')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2019')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2020', 'qtd_familias_2020', 'IDHM Educação 2020', 
               'IDHM Renda 2020', 'Índice de Atkinson - Educação 2020', 
               'Índice de Atkinson - Renda 2020', 'Renda per capita 2020', 
               'Índice de Gini 2020', 'Taxa_Desocupacao_2020', 
               'Nivel_Ocupacao_2020', 'Taxa_Participacao_2020']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2020", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2020')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2020')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2021', 'qtd_familias_2021', 'IDHM Educação 2021', 
               'IDHM Renda 2021', 'Índice de Atkinson - Educação 2021', 
               'Índice de Atkinson - Renda 2021', 'Renda per capita 2021', 
               'Índice de Gini 2021', 'Taxa_Desocupacao_2021', 
               'Nivel_Ocupacao_2021', 'Taxa_Participacao_2021']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2021", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2021')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2021')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2023', 'qtd_familias_2023']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EF2023", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EF2023')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EF2023')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## correlação dos valores de cada ano usando o abandono do Encino Medio

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2012': 'qtd_familias_2012'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2012': 'valor_medio_2012'})

dados_df[['Abandono_EM2012','valor_medio_2012','qtd_familias_2012','IDHM Educação 2012','IDHM Renda 2012','Índice de Atkinson - Educação 2012','Índice de Atkinson - Renda 2012','Renda per capita 2012','Índice de Gini 2012','Taxa_Desocupacao_2012','Nivel_Ocupacao_2012','Taxa_Participacao_2012']].corr()
# Out:
#                                     Abandono_EM2012  valor_medio_2012  \
# Abandono_EM2012                            1.000000         -0.264269
# valor_medio_2012                          -0.264269          1.000000
# qtd_familias_2012                          0.892195         -0.228185
# IDHM Educação 2012                        -0.014588         -0.350410
# IDHM Renda 2012                            0.034472         -0.532823
# Índice de Atkinson - Educação 2012        -0.053774          0.342438
# Índice de Atkinson - Renda 2012           -0.070611          0.416201
# Renda per capita 2012                      0.030319         -0.555202
# Índice de Gini 2012                        0.011308          0.298905
# Taxa_Desocupacao_2012                      0.128646          0.314345
# Nivel_Ocupacao_2012                       -0.027587         -0.349337
# Taxa_Participacao_2012                     0.015345         -0.318316
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2012','valor_medio_2012','qtd_familias_2012','IDHM Educação 2012','IDHM Renda 2012','Índice de Atkinson - Educação 2012','Índice de Atkinson - Renda 2012','Renda per capita 2012','Índice de Gini 2012','Taxa_Desocupacao_2012','Nivel_Ocupacao_2012','Taxa_Participacao_2012']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2013': 'qtd_familias_2013'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2013': 'valor_medio_2013'})

dados_df[['Abandono_EM2013','valor_medio_2013','qtd_familias_2013','IDHM Educação 2013','IDHM Renda 2013','Índice de Atkinson - Educação 2013','Índice de Atkinson - Renda 2013','Renda per capita 2013','Índice de Gini 2013','Taxa_Desocupacao_2013','Nivel_Ocupacao_2013','Taxa_Participacao_2013']].corr()
# Out:
#                                     Abandono_EM2013  valor_medio_2013  \
# Abandono_EM2013                            1.000000         -0.220373
# valor_medio_2013                          -0.220373          1.000000
# qtd_familias_2013                          0.789374         -0.125897
# IDHM Educação 2013                         0.085468         -0.397830
# IDHM Renda 2013                            0.093604         -0.650077
# Índice de Atkinson - Educação 2013        -0.178772          0.537714
# Índice de Atkinson - Renda 2013           -0.153335          0.448437
# Renda per capita 2013                      0.089520         -0.634391
# Índice de Gini 2013                       -0.116469          0.398907
# Taxa_Desocupacao_2013                     -0.004013          0.394445
# Nivel_Ocupacao_2013                        0.076598         -0.502167
# Taxa_Participacao_2013                     0.097596         -0.480068
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2013','valor_medio_2013','qtd_familias_2013','IDHM Educação 2013','IDHM Renda 2013','Índice de Atkinson - Educação 2013','Índice de Atkinson - Renda 2013','Renda per capita 2013','Índice de Gini 2013','Taxa_Desocupacao_2013','Nivel_Ocupacao_2013','Taxa_Participacao_2013']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2014': 'qtd_familias_2014'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2014': 'valor_medio_2014'})

dados_df[['Abandono_EM2014','valor_medio_2014','qtd_familias_2014','IDHM Educação 2014','IDHM Renda 2014','Índice de Atkinson - Educação 2014','Índice de Atkinson - Renda 2014','Renda per capita 2014','Índice de Gini 2014','Taxa_Desocupacao_2014','Nivel_Ocupacao_2014','Taxa_Participacao_2014']].corr()
# Out:
#                                     Abandono_EM2014  valor_medio_2014  \
# Abandono_EM2014                            1.000000         -0.184851
# valor_medio_2014                          -0.184851          1.000000
# qtd_familias_2014                          0.805795         -0.108491
# IDHM Educação 2014                         0.108353         -0.390789
# IDHM Renda 2014                            0.097461         -0.661275
# Índice de Atkinson - Educação 2014        -0.223263          0.552078
# Índice de Atkinson - Renda 2014           -0.170878          0.460338
# Renda per capita 2014                      0.102551         -0.633418
# Índice de Gini 2014                       -0.062750          0.324163
# Taxa_Desocupacao_2014                      0.014505          0.396711
# Nivel_Ocupacao_2014                        0.081870         -0.494133
# Taxa_Participacao_2014                     0.111346         -0.468858
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2014','valor_medio_2014','qtd_familias_2014','IDHM Educação 2014','IDHM Renda 2014','Índice de Atkinson - Educação 2014','Índice de Atkinson - Renda 2014','Renda per capita 2014','Índice de Gini 2014','Taxa_Desocupacao_2014','Nivel_Ocupacao_2014','Taxa_Participacao_2014']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2015': 'qtd_familias_2015'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2015': 'valor_medio_2015'})

dados_df[['Abandono_EM2015','valor_medio_2015','qtd_familias_2015','IDHM Educação 2015','IDHM Renda 2015','Índice de Atkinson - Educação 2015','Índice de Atkinson - Renda 2015','Renda per capita 2015','Índice de Gini 2015','Taxa_Desocupacao_2015','Nivel_Ocupacao_2015','Taxa_Participacao_2015']].corr()
# Out:
#                                     Abandono_EM2015  valor_medio_2015  \
# Abandono_EM2015                            1.000000         -0.156376
# valor_medio_2015                          -0.156376          1.000000
# qtd_familias_2015                          0.730778         -0.071279
# IDHM Educação 2015                         0.087709         -0.429818
# IDHM Renda 2015                            0.029664         -0.596642
# Índice de Atkinson - Educação 2015        -0.181449          0.532161
# Índice de Atkinson - Renda 2015           -0.216161          0.621517
# Renda per capita 2015                      0.026295         -0.555374
# Índice de Gini 2015                       -0.194478          0.486416
# Taxa_Desocupacao_2015                     -0.082765          0.417694
# Nivel_Ocupacao_2015                        0.118935         -0.512187
# Taxa_Participacao_2015                     0.120733         -0.484071
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2015','valor_medio_2015','qtd_familias_2015','IDHM Educação 2015','IDHM Renda 2015','Índice de Atkinson - Educação 2015','Índice de Atkinson - Renda 2015','Renda per capita 2015','Índice de Gini 2015','Taxa_Desocupacao_2015','Nivel_Ocupacao_2015','Taxa_Participacao_2015']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2016': 'qtd_familias_2016'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2016': 'valor_medio_2016'})

dados_df[['Abandono_EM2016','valor_medio_2016','qtd_familias_2016','IDHM Educação 2016','IDHM Renda 2016','Índice de Atkinson - Educação 2016','Índice de Atkinson - Renda 2016','Renda per capita 2016','Índice de Gini 2016','Taxa_Desocupacao_2016','Nivel_Ocupacao_2016','Taxa_Participacao_2016']].corr()
# Out:
#                                     Abandono_EM2016  valor_medio_2016  \
# Abandono_EM2016                            1.000000         -0.169851
# valor_medio_2016                          -0.169851          1.000000
# qtd_familias_2016                          0.795509         -0.071292
# IDHM Educação 2016                         0.147256         -0.407189
# IDHM Renda 2016                            0.102189         -0.643526
# Índice de Atkinson - Educação 2016        -0.253181          0.505397
# Índice de Atkinson - Renda 2016           -0.150534          0.556844
# Renda per capita 2016                      0.110716         -0.596152
# Índice de Gini 2016                       -0.081152          0.475825
# Taxa_Desocupacao_2016                      0.006045          0.417668
# Nivel_Ocupacao_2016                        0.060310         -0.512163
# Taxa_Participacao_2016                     0.082332         -0.484050
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2016','valor_medio_2016','qtd_familias_2016','IDHM Educação 2016','IDHM Renda 2016','Índice de Atkinson - Educação 2016','Índice de Atkinson - Renda 2016','Renda per capita 2016','Índice de Gini 2016','Taxa_Desocupacao_2016','Nivel_Ocupacao_2016','Taxa_Participacao_2016']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2017': 'qtd_familias_2017'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2017': 'valor_medio_2017'})

dados_df[['Abandono_EM2017','valor_medio_2017','qtd_familias_2017','IDHM Educação 2017','IDHM Renda 2017','Índice de Atkinson - Educação 2017','Índice de Atkinson - Renda 2017','Renda per capita 2017','Índice de Gini 2017','Taxa_Desocupacao_2017','Nivel_Ocupacao_2017','Taxa_Participacao_2017']].corr()
# Out:
#                                     Abandono_EM2017  valor_medio_2017  \
# Abandono_EM2017                            1.000000         -0.164317
# valor_medio_2017                          -0.164317          1.000000
# qtd_familias_2017                          0.774166         -0.047753
# IDHM Educação 2017                         0.190195         -0.422363
# IDHM Renda 2017                            0.141314         -0.627108
# Índice de Atkinson - Educação 2017        -0.216361          0.495842
# Índice de Atkinson - Renda 2017           -0.127134          0.603920
# Renda per capita 2017                      0.122065         -0.575993
# Índice de Gini 2017                        0.012667          0.495102
# Taxa_Desocupacao_2017                     -0.012086          0.443059
# Nivel_Ocupacao_2017                        0.120612         -0.519338
# Taxa_Participacao_2017                     0.150206         -0.483398
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2017','valor_medio_2017','qtd_familias_2017','IDHM Educação 2017','IDHM Renda 2017','Índice de Atkinson - Educação 2017','Índice de Atkinson - Renda 2017','Renda per capita 2017','Índice de Gini 2017','Taxa_Desocupacao_2017','Nivel_Ocupacao_2017','Taxa_Participacao_2017']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2018': 'qtd_familias_2018'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2018': 'valor_medio_2018'})

dados_df[['Abandono_EM2018','valor_medio_2018','qtd_familias_2018','IDHM Educação 2018','IDHM Renda 2018','Índice de Atkinson - Educação 2018','Índice de Atkinson - Renda 2018','Renda per capita 2018','Índice de Gini 2018','Taxa_Desocupacao_2018','Nivel_Ocupacao_2018','Taxa_Participacao_2018']].corr()
# Out:
#                                     Abandono_EM2018  valor_medio_2018  \
# Abandono_EM2018                            1.000000         -0.121317
# valor_medio_2018                          -0.121317          1.000000
# qtd_familias_2018                          0.761826         -0.054561
# IDHM Educação 2018                         0.054887         -0.355512
# IDHM Renda 2018                            0.084351         -0.590735
# Índice de Atkinson - Educação 2018        -0.172425          0.456788
# Índice de Atkinson - Renda 2018           -0.168509          0.624845
# Renda per capita 2018                      0.085672         -0.548376
# Índice de Gini 2018                       -0.023992          0.487757
# Taxa_Desocupacao_2018                      0.009192          0.448228
# Nivel_Ocupacao_2018                        0.115070         -0.509117
# Taxa_Participacao_2018                     0.151090         -0.468423
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2018','valor_medio_2018','qtd_familias_2018','IDHM Educação 2018','IDHM Renda 2018','Índice de Atkinson - Educação 2018','Índice de Atkinson - Renda 2018','Renda per capita 2018','Índice de Gini 2018','Taxa_Desocupacao_2018','Nivel_Ocupacao_2018','Taxa_Participacao_2018']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2019': 'qtd_familias_2019'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2019': 'valor_medio_2019'})

dados_df[['Abandono_EM2019','valor_medio_2019','qtd_familias_2019','IDHM Educação 2019','IDHM Renda 2019','Índice de Atkinson - Educação 2019','Índice de Atkinson - Renda 2019','Renda per capita 2019','Índice de Gini 2019','Taxa_Desocupacao_2019','Nivel_Ocupacao_2019','Taxa_Participacao_2019']].corr()
# Out:
#                                     Abandono_EM2019  valor_medio_2019  \
# Abandono_EM2019                            1.000000         -0.077938
# valor_medio_2019                          -0.077938          1.000000
# qtd_familias_2019                          0.753720         -0.060641
# IDHM Educação 2019                         0.092658         -0.244349
# IDHM Renda 2019                            0.095396         -0.574643
# Índice de Atkinson - Educação 2019        -0.214162          0.415517
# Índice de Atkinson - Renda 2019           -0.113682          0.625092
# Renda per capita 2019                      0.098123         -0.515774
# Índice de Gini 2019                       -0.012068          0.490974
# Taxa_Desocupacao_2019                      0.063077          0.442350
# Nivel_Ocupacao_2019                        0.069796         -0.487003
# Taxa_Participacao_2019                     0.115133         -0.442730
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2019','valor_medio_2019','qtd_familias_2019','IDHM Educação 2019','IDHM Renda 2019','Índice de Atkinson - Educação 2019','Índice de Atkinson - Renda 2019','Renda per capita 2019','Índice de Gini 2019','Taxa_Desocupacao_2019','Nivel_Ocupacao_2019','Taxa_Participacao_2019']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2020': 'qtd_familias_2020'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2020': 'valor_medio_2020'})

dados_df[['Abandono_EM2020','valor_medio_2020','qtd_familias_2020','IDHM Educação 2020','IDHM Renda 2020','Índice de Atkinson - Educação 2020','Índice de Atkinson - Renda 2020','Renda per capita 2020','Índice de Gini 2020','Taxa_Desocupacao_2020','Nivel_Ocupacao_2020','Taxa_Participacao_2020']].corr()
# Out:
#                                     Abandono_EM2020  valor_medio_2020  \
# Abandono_EM2020                            1.000000         -0.060957
# valor_medio_2020                          -0.060957          1.000000
# qtd_familias_2020                          0.305926         -0.195147
# IDHM Educação 2020                         0.152988         -0.104627
# IDHM Renda 2020                            0.163215         -0.405982
# Índice de Atkinson - Educação 2020        -0.129112          0.200525
# Índice de Atkinson - Renda 2020           -0.376446          0.275748
# Renda per capita 2020                      0.136018         -0.357143
# Índice de Gini 2020                       -0.304893          0.135531
# Taxa_Desocupacao_2020                     -0.242535          0.175876
# Nivel_Ocupacao_2020                        0.188900         -0.198848
# Taxa_Participacao_2020                     0.147533         -0.183144
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2020','valor_medio_2020','qtd_familias_2020','IDHM Educação 2020','IDHM Renda 2020','Índice de Atkinson - Educação 2020','Índice de Atkinson - Renda 2020','Renda per capita 2020','Índice de Gini 2020','Taxa_Desocupacao_2020','Nivel_Ocupacao_2020','Taxa_Participacao_2020']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2021': 'qtd_familias_2021'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2021': 'valor_medio_2021'})

dados_df[['Abandono_EM2021','valor_medio_2021','qtd_familias_2021','IDHM Educação 2021','IDHM Renda 2021','Índice de Atkinson - Educação 2021','Índice de Atkinson - Renda 2021','Renda per capita 2021','Índice de Gini 2021','Taxa_Desocupacao_2021','Nivel_Ocupacao_2021','Taxa_Participacao_2021']].corr()
# Out:
#                                     Abandono_EM2021  valor_medio_2021  \
# Abandono_EM2021                            1.000000         -0.071626
# valor_medio_2021                          -0.071626          1.000000
# qtd_familias_2021                          0.724861         -0.165351
# IDHM Educação 2021                         0.021418         -0.343736
# IDHM Renda 2021                            0.008634         -0.367424
# Índice de Atkinson - Educação 2021        -0.047416          0.193753
# Índice de Atkinson - Renda 2021           -0.051662          0.367613
# Renda per capita 2021                      0.023676         -0.330864
# Índice de Gini 2021                       -0.016663          0.259657
# Taxa_Desocupacao_2021                      0.106660          0.244356
# Nivel_Ocupacao_2021                        0.023988         -0.270099
# Taxa_Participacao_2021                     0.070482         -0.245624
#
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2021','valor_medio_2021','qtd_familias_2021','IDHM Educação 2021','IDHM Renda 2021','Índice de Atkinson - Educação 2021','Índice de Atkinson - Renda 2021','Renda per capita 2021','Índice de Gini 2021','Taxa_Desocupacao_2021','Nivel_Ocupacao_2021','Taxa_Participacao_2021']].corr())
plt.show()

# %%
dados_df = dados_df.rename(columns={'qtd_familias_beneficiarias_bolsa_familia_ajustado_2023': 'qtd_familias_2023'})
dados_df = dados_df.rename(columns={'valor_medio_bf_ajustado_2023': 'valor_medio_2023'})

dados_df[['Abandono_EM2023','valor_medio_2023','qtd_familias_2023']].corr()
# Out:
#                    Abandono_EM2023  valor_medio_2023  qtd_familias_2023
# Abandono_EM2023           1.000000         -0.338879            0.72077
# valor_medio_2023         -0.338879          1.000000           -0.42371
# qtd_familias_2023         0.720770         -0.423710            1.00000

# %%
plt.figure(figsize=(9,9))
sns.heatmap(dados_df[['Abandono_EM2023','valor_medio_2023','qtd_familias_2023']].corr())
plt.show()

# %% [markdown]
# ### plotando graficos de disperção

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2012', 'qtd_familias_2012', 'IDHM Educação 2012', 
               'IDHM Renda 2012', 'Índice de Atkinson - Educação 2012', 
               'Índice de Atkinson - Renda 2012', 'Renda per capita 2012', 
               'Índice de Gini 2012', 'Taxa_Desocupacao_2012', 
               'Nivel_Ocupacao_2012', 'Taxa_Participacao_2012']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2012", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2012')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2012')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2013', 'qtd_familias_2013', 'IDHM Educação 2013', 
               'IDHM Renda 2013', 'Índice de Atkinson - Educação 2013', 
               'Índice de Atkinson - Renda 2013', 'Renda per capita 2013', 
               'Índice de Gini 2013', 'Taxa_Desocupacao_2013', 
               'Nivel_Ocupacao_2013', 'Taxa_Participacao_2013']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2013", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2013')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2013')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2014', 'qtd_familias_2014', 'IDHM Educação 2014', 
               'IDHM Renda 2014', 'Índice de Atkinson - Educação 2014', 
               'Índice de Atkinson - Renda 2014', 'Renda per capita 2014', 
               'Índice de Gini 2014', 'Taxa_Desocupacao_2014', 
               'Nivel_Ocupacao_2014', 'Taxa_Participacao_2014']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2014", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2014')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2014')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2015', 'qtd_familias_2015', 'IDHM Educação 2015', 
               'IDHM Renda 2015', 'Índice de Atkinson - Educação 2015', 
               'Índice de Atkinson - Renda 2015', 'Renda per capita 2015', 
               'Índice de Gini 2015', 'Taxa_Desocupacao_2015', 
               'Nivel_Ocupacao_2015', 'Taxa_Participacao_2015']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2015", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2015')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2015')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2016', 'qtd_familias_2016', 'IDHM Educação 2016', 
               'IDHM Renda 2016', 'Índice de Atkinson - Educação 2016', 
               'Índice de Atkinson - Renda 2016', 'Renda per capita 2016', 
               'Índice de Gini 2016', 'Taxa_Desocupacao_2016', 
               'Nivel_Ocupacao_2016', 'Taxa_Participacao_2016']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2016", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2016')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2016')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2017', 'qtd_familias_2017', 'IDHM Educação 2017', 
               'IDHM Renda 2017', 'Índice de Atkinson - Educação 2017', 
               'Índice de Atkinson - Renda 2017', 'Renda per capita 2017', 
               'Índice de Gini 2017', 'Taxa_Desocupacao_2017', 
               'Nivel_Ocupacao_2017', 'Taxa_Participacao_2017']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2017", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2017')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2017')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2018', 'qtd_familias_2018', 'IDHM Educação 2018', 
               'IDHM Renda 2018', 'Índice de Atkinson - Educação 2018', 
               'Índice de Atkinson - Renda 2018', 'Renda per capita 2018', 
               'Índice de Gini 2018', 'Taxa_Desocupacao_2018', 
               'Nivel_Ocupacao_2018', 'Taxa_Participacao_2018']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2018", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2018')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2018')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2019', 'qtd_familias_2019', 'IDHM Educação 2019', 
               'IDHM Renda 2019', 'Índice de Atkinson - Educação 2019', 
               'Índice de Atkinson - Renda 2019', 'Renda per capita 2019', 
               'Índice de Gini 2019', 'Taxa_Desocupacao_2019', 
               'Nivel_Ocupacao_2019', 'Taxa_Participacao_2019']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2019", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2019')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2019')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2020', 'qtd_familias_2020', 'IDHM Educação 2020', 
               'IDHM Renda 2020', 'Índice de Atkinson - Educação 2020', 
               'Índice de Atkinson - Renda 2020', 'Renda per capita 2020', 
               'Índice de Gini 2020', 'Taxa_Desocupacao_2020', 
               'Nivel_Ocupacao_2020', 'Taxa_Participacao_2020']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2020", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2020')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2020')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2021', 'qtd_familias_2021', 'IDHM Educação 2021', 
               'IDHM Renda 2021', 'Índice de Atkinson - Educação 2021', 
               'Índice de Atkinson - Renda 2021', 'Renda per capita 2021', 
               'Índice de Gini 2021', 'Taxa_Desocupacao_2021', 
               'Nivel_Ocupacao_2021', 'Taxa_Participacao_2021']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2021", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2021')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2021')


plt.tight_layout()
plt.show()

# %%
sns.set_style("white")


plt.figure(figsize=(12, 10))


variaveis_x = ['valor_medio_2023', 'qtd_familias_2023']


for i, var_x in enumerate(variaveis_x, 1):
    plt.subplot(4, 3, i)  
    sns.regplot(x=var_x, y="Abandono_EM2023", data=dados_df, 
                scatter_kws={'color': 'blue'}, line_kws={'color': 'red', 'linewidth': 2})
    plt.title(f'Gráfico de Dispersão: {var_x} vs Abandono_EM2023')
    plt.xlabel(var_x)
    plt.ylabel('Abandono_EM2023')


plt.tight_layout()
plt.show()
